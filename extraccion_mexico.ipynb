# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
data=pd.read_csv('listings_50_outliers_mexico.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26281 entries, 0 to 26280
# Data columns (total 76 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Unnamed: 0                                    26281 non-null  int64
#  1   listing_url                                   26281 non-null  object
#  2   last_scraped                                  26281 non-null  object
#  3   source                                        26281 non-null  object
#  4   name                                          26281 non-null  object
#  5   description                                   25513 non-null  object
#  6   neighborhood_overview                         15110 non-null  object
#  7   picture_url                                   26281 non-null  object
#  8   host_url                                      26281 non-null  object
# ...

# %%
freq_tbl(data)
# Out:
#                                             listing_url  frequency  \
# 0                    https://www.airbnb.com/rooms/35797          1
# 1       https://www.airbnb.com/rooms/932128744565585326          1
# 2       https://www.airbnb.com/rooms/933505833183244283          1
# 3       https://www.airbnb.com/rooms/933472190275456348          1
# 4       https://www.airbnb.com/rooms/933460293599875386          1
# ...                                                 ...        ...
# 26276             https://www.airbnb.com/rooms/48422338          1
# 26277             https://www.airbnb.com/rooms/48419939          1
# 26278             https://www.airbnb.com/rooms/48419315          1
# 26279             https://www.airbnb.com/rooms/48417971          1
# 26280  https://www.airbnb.com/rooms/1319509843525848258          1
#
#        percentage  cumulative_perc
# 0        0.000038         0.000038
# 1        0.000038         0.000076
# 2        0.000038         0.000114
# ...

# %%
table1 = freq_tbl(data['host_response_time'])
table1
# Out:
#    host_response_time  frequency  percentage  cumulative_perc
# 0      within an hour      18389    0.699707         0.795751
# 1  within a few hours       2346    0.089266         0.897269
# 2        within a day       1280    0.048704         0.952659
# 3  a few days or more       1094    0.041627         1.000000

# %%
table2=table1.drop(['percentage', 'cumulative_perc'], axis=1)

# %%
filtro=table2[table2['frequency']>=1094]
filtro
# Out:
#    host_response_time  frequency
# 0      within an hour      18389
# 1  within a few hours       2346
# 2        within a day       1280
# 3  a few days or more       1094

# %%
filtro_index=filtro.set_index('host_response_time')
filtro_index
# Out:
#                     frequency
# host_response_time
# within an hour          18389
# within a few hours       2346
# within a day             1280
# a few days or more       1094

# %%
filtro_index["frequency"].plot(kind='pie', figsize=(10,5),shadow=True, autopct="%0.1f%%")
# Out:
# <Axes: ylabel='frequency'>

# %%
table3 = freq_tbl(data['host_response_rate'])
table3
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18256\3420704231.py in ?()
#       2 table3
#       3 table4=table3.drop(['percentage', 'cumulative_perc'], axis=1)
#       4 table4
#       5 filtro2=table2[table2['frequency']>=577]
# ----> 6 filtro_index2=filtro2.set_index('host_response_rate')
#       7 filtro_index2
#       8
#
# c:\Users\hegbj\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['host_response_rate'] are in the columns"

# %%
table4=table3.drop(['percentage', 'cumulative_perc'], axis=1)
table4
# Out:
#    host_response_rate  frequency
# 0                100%      17643
# 1                 90%        648
# 2                 98%        586
# 3                 99%        582
# 4                  0%        577
# ..                ...        ...
# 63                 9%          1
# 64                53%          1
# 65                12%          1
# 66                49%          1
# 67                 7%          1
#
# [68 rows x 2 columns]

# %%
filtro2=table4[table4['frequency']>=577]
filtro2
# Out:
#   host_response_rate  frequency
# 0               100%      17643
# 1                90%        648
# 2                98%        586
# 3                99%        582
# 4                 0%        577

# %%
filtro_index2=filtro2.set_index('host_response_rate')
filtro_index2
# Out:
#                     frequency
# host_response_rate
# 100%                    17643
# 90%                       648
# 98%                       586
# 99%                       582
# 0%                        577

# %%
filtro_index.plot(kind='bar',width=0.8, figsize=(10,10),color="pink")
plt.title('host_response_rate')
plt.xlabel('taza de respuesta del anfitrion')
plt.ylabel('frecuencia')
# Out:
# Text(0, 0.5, 'frecuencia')

# %%
table5 = freq_tbl(data['host_is_superhost'])
table5
# Out:
#   host_is_superhost  frequency  percentage  cumulative_perc
# 0                 f      14884    0.566341         0.597775
# 1                 t      10015    0.381074         1.000000

# %%
table6=table5.drop(['percentage', 'cumulative_perc'], axis=1)
table6
# Out:
#   host_is_superhost  frequency
# 0                 f      14884
# 1                 t      10015

# %%
filtro_index3=table6.set_index('host_is_superhost')
filtro_index3
# Out:
#                    frequency
# host_is_superhost
# f                      14884
# t                      10015

# %%
filtro_index3["a"].plot(kind='pie', figsize=(10,5),shadow=True, autopct="%0.1f%%")
# Out:
# <Axes: ylabel='frequency'>
